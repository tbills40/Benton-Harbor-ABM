# %%
#importations 
import pandas as pd
import pandas as pd
import numpy as np
from scipy.spatial import distance
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#locate files from computer

# %%
cd//Users/esekhaigbe/Downloads/codes
# Out:
# /Users/esekhaigbe/Downloads/codes

# %%
df = pd.read_csv('perpub.csv')
df['Person'] = df['HOUSEID'].map(str) + '-' + df['PERSONID'].map(str)
df
# Out:
#          HOUSEID  PERSONID  R_AGE  EDUC  R_HISP  R_RELAT  R_SEX  R_RACE  \
# 0       30000007         1     67     3       2        1      2       2
# 1       30000007         2     66     3       2        2      1       2
# 2       30000007         3     28     2       2        3      2       2
# 3       30000008         1     55     5       2        1      1       1
# 4       30000008         2     49     4       2        2      2       1
# ...          ...       ...    ...   ...     ...      ...    ...     ...
# 264229  40794301         4     18     2       2        3      2       1
# 264230  40794301         5     14     1       2        3      2       1
# 264231  40794301         6     12    -1       2        3      2       1
# 264232  40794301         7      8    -1       2        3      2       1
# 264233  50515573         1     52     5       2        1      1       1
#
#         PRMACT  PAYPROF  ...    WTPERFIN  HBHUR  HTHTNRNT  HTPPOPDN  HTRESDN  \
# ...

# %%
tour = pd.read_csv('2017tourfile.csv')
tour
# Out:
#             Person  Tour
# 0       30000007-1   1.0
# 1       30000007-2   1.0
# 2       30000007-3   1.0
# 3       30000008-1   1.0
# 4       30000012-1   1.0
# ...            ...   ...
# 206585  40794293-2   1.0
# 206586  40794301-2   1.0
# 206587  40794301-3   1.0
# 206588  40794301-6   1.0
# 206589  50515573-1   1.0
#
# [206590 rows x 2 columns]

# %%
stop = pd.read_csv('2017stopfile.csv')
stop
# Out:
#             Person  Stop
# 0       30000012-1   7.0
# 1       30000019-1   1.0
# 2       30000019-2   1.0
# 3       30000029-1   2.0
# 4       30000029-2   5.0
# ...            ...   ...
# 177884  40794293-1   1.0
# 177885  40794301-2   3.0
# 177886  40794301-3   3.0
# 177887  40794301-6   1.0
# 177888  50515573-1   3.0
#
# [177889 rows x 2 columns]

# %%
pd = pd.read_csv('2017pdestinationfile.csv')
pd
# Out:
#             Person  P_Destination
# 0       30000007-1            1.0
# 1       30000007-2            1.0
# 2       30000007-3            1.0
# 3       30000008-1            1.0
# 4       30000012-1            1.0
# ...            ...            ...
# 102768  40794260-2            1.0
# 102769  40794260-3            1.0
# 102770  40794293-2            1.0
# 102771  40794301-2            1.0
# 102772  50515573-1            1.0
#
# [102773 rows x 2 columns]

# %%
tourstop=tour.merge(stop, on='Person', how='left')
tourstop
# Out:
#             Person  Tour  Stop
# 0       30000007-1   1.0   NaN
# 1       30000007-2   1.0   NaN
# 2       30000007-3   1.0   NaN
# 3       30000008-1   1.0   NaN
# 4       30000012-1   1.0   7.0
# ...            ...   ...   ...
# 206585  40794293-2   1.0   NaN
# 206586  40794301-2   1.0   3.0
# 206587  40794301-3   1.0   3.0
# 206588  40794301-6   1.0   1.0
# 206589  50515573-1   1.0   3.0
#
# [206590 rows x 3 columns]

# %%
tourstoppd=tourstop.merge(pd, on='Person', how='left')
tourstoppd
# Out:
#             Person  Tour  Stop  P_Destination
# 0       30000007-1   1.0   NaN            1.0
# 1       30000007-2   1.0   NaN            1.0
# 2       30000007-3   1.0   NaN            1.0
# 3       30000008-1   1.0   NaN            1.0
# 4       30000012-1   1.0   7.0            1.0
# ...            ...   ...   ...            ...
# 206585  40794293-2   1.0   NaN            1.0
# 206586  40794301-2   1.0   3.0            1.0
# 206587  40794301-3   1.0   3.0            NaN
# 206588  40794301-6   1.0   1.0            NaN
# 206589  50515573-1   1.0   3.0            1.0
#
# [206590 rows x 4 columns]

# %%
final=tourstoppd.merge(df, on='Person', how='left')
final
# Out:
#             Person  Tour  Stop  P_Destination   HOUSEID  PERSONID  R_AGE  \
# 0       30000007-1   1.0   NaN            1.0  30000007         1     67
# 1       30000007-2   1.0   NaN            1.0  30000007         2     66
# 2       30000007-3   1.0   NaN            1.0  30000007         3     28
# 3       30000008-1   1.0   NaN            1.0  30000008         1     55
# 4       30000012-1   1.0   7.0            1.0  30000012         1     45
# ...            ...   ...   ...            ...       ...       ...    ...
# 206585  40794293-2   1.0   NaN            1.0  40794293         2     62
# 206586  40794301-2   1.0   3.0            1.0  40794301         2     59
# 206587  40794301-3   1.0   3.0            NaN  40794301         3     22
# 206588  40794301-6   1.0   1.0            NaN  40794301         6     12
# 206589  50515573-1   1.0   3.0            1.0  50515573         1     52
#
#         EDUC  R_HISP  R_RELAT  ...  SMPLSRCE    WTPERFIN  HBHUR  HTHTNRNT  \
# ...

# %%
#df1=final.dropna(subset=['Tour'], inplace=True)

#drop rows with missing values in 'assists' column
#final.dropna(subset = ['Tour'], inplace=True)
#final

# %%
df1

# %%
final.to_csv('2017mergedontournhts1.csv')

# %%
df1=df.merge(tour, on='Person', how='left')
df1
# Out:
#          HOUSEID  PERSONID  R_AGE  EDUC  R_HISP  R_RELAT  R_SEX  R_RACE  \
# 0       30000007         1     67     3       2        1      2       2
# 1       30000007         2     66     3       2        2      1       2
# 2       30000007         3     28     2       2        3      2       2
# 3       30000008         1     55     5       2        1      1       1
# 4       30000008         2     49     4       2        2      2       1
# ...          ...       ...    ...   ...     ...      ...    ...     ...
# 264229  40794301         4     18     2       2        3      2       1
# 264230  40794301         5     14     1       2        3      2       1
# 264231  40794301         6     12    -1       2        3      2       1
# 264232  40794301         7      8    -1       2        3      2       1
# 264233  50515573         1     52     5       2        1      1       1
#
#         PRMACT  PAYPROF  ...  HBHUR  HTHTNRNT  HTPPOPDN  HTRESDN  HTEEMPDN  \
# ...

# %%
df2=df1.merge(stop, on='Person', how='left')
df2
# Out:
#          HOUSEID  PERSONID  R_AGE  EDUC  R_HISP  R_RELAT  R_SEX  R_RACE  \
# 0       30000007         1     67     3       2        1      2       2
# 1       30000007         2     66     3       2        2      1       2
# 2       30000007         3     28     2       2        3      2       2
# 3       30000008         1     55     5       2        1      1       1
# 4       30000008         2     49     4       2        2      2       1
# ...          ...       ...    ...   ...     ...      ...    ...     ...
# 264229  40794301         4     18     2       2        3      2       1
# 264230  40794301         5     14     1       2        3      2       1
# 264231  40794301         6     12    -1       2        3      2       1
# 264232  40794301         7      8    -1       2        3      2       1
# 264233  50515573         1     52     5       2        1      1       1
#
#         PRMACT  PAYPROF  ...  HTHTNRNT  HTPPOPDN  HTRESDN  HTEEMPDN  HBHTNRNT  \
# ...

# %%
df3=df2.merge(pd, on='Person', how='left')
df3
# Out:
#          HOUSEID  PERSONID  R_AGE  EDUC  R_HISP  R_RELAT  R_SEX  R_RACE  \
# 0       30000007         1     67     3       2        1      2       2
# 1       30000007         2     66     3       2        2      1       2
# 2       30000007         3     28     2       2        3      2       2
# 3       30000008         1     55     5       2        1      1       1
# 4       30000008         2     49     4       2        2      2       1
# ...          ...       ...    ...   ...     ...      ...    ...     ...
# 264229  40794301         4     18     2       2        3      2       1
# 264230  40794301         5     14     1       2        3      2       1
# 264231  40794301         6     12    -1       2        3      2       1
# 264232  40794301         7      8    -1       2        3      2       1
# 264233  50515573         1     52     5       2        1      1       1
#
#         PRMACT  PAYPROF  ...  HTPPOPDN  HTRESDN  HTEEMPDN  HBHTNRNT  HBPPOPDN  \
# ...

# %%
# drop all rows that contain 'Coca Cola'
#df4 = df3.drop(df3[df3['Tour'] == 'NaN'].index)
#df4
#df4 = df3.dropna()


df4=df3.dropna(subset=['Tour'], inplace=True)
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 7>()
#       1 # drop all rows that contain 'Coca Cola'
#       2 #df4 = df3.drop(df3[df3['Tour'] == 'NaN'].index)
#       3 #df4
#       4 #df4 = df3.dropna()
# ----> 7 df4=df3.dropna(subset=['Tour'], inplace=True)
#       8 df4
#
# NameError: name 'df3' is not defined

# %%
df3.to_csv('2017mergednhts.csv')

# %%
df1 = pd.merge(left=df, right=tour, how='left', left_on='Person', right_on='Person')
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df1 = pd.merge(left=df, right=tour, how='left', left_on='Person', right_on='Person')
#       2 df1
#
# TypeError: merge() got an unexpected keyword argument 'left'

# %%
df1=df.merge(tour, left_on='Person', right_on='Person')

df1
# Out:
#        HOUSEID_x  PERSONID_x      WTPERFIN    WTPERFIN5D    WTPERFIN2D  R_AGE  \
# 0     9000013002           1   3938.688806      0.000000  13363.809355     39
# 1     9000013002           2   5409.514573      0.000000  19360.094919     42
# 2     9000013002           4   6214.108740      0.000000  27109.336829      5
# 3     9000013016           1   3183.420810   4177.234452      0.000000     32
# 4     9000013016           2   3213.680996   4010.809995      0.000000     41
# ...          ...         ...           ...           ...           ...    ...
# 9659  9000217992           2  52878.363815  72081.134110      0.000000     33
# 9660  9000218006           1   6453.550836   8921.618161      0.000000     43
# 9661  9000218006           2   6678.701098   8744.171368      0.000000     15
# 9662  9000218013           1   6787.592149   8548.020669      0.000000     78
# 9663  9000218040           1  11455.059845  12936.571349      0.000000     58
#
# ...

# %% [raw]
# df1=df.merge(tour[['Person', 'Tour']], on='Person')
# df1

# %% [raw]
# ### merged_df = pd.merge(df, tour, on='Person')
# merged_df
