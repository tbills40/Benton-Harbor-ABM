# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#locate files from computer

# %%
#Import anmd merger for demographics get the mean
af = pd.read_csv('DCmergedfile.csv')
#mean for demographics 
aff = af.groupby(['PERSON_ID']).mean()
aff
# Out:
# /var/folders/fs/02s140qd6n97_sck15lvgycm0000gn/T/ipykernel_801/2388051081.py:2: DtypeWarning: Columns (26,27,29,31,54,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   af = pd.read_csv('DCmergedfile.csv')
#              Unnamed: 0  HOUSEHOLD_ID_x  PERSNO        TRIPID   Dwelltime  \
# PERSON_ID
# 14000027101         2.0     140000271.0     1.0  1.400000e+12  -29.200000
# 14000027103         5.5     140000271.0     3.0  1.400000e+12  -78.000000
# 14000028001         9.0     140000280.0     1.0  1.400000e+12   25.600000
# 14000028401        14.0     140000284.0     1.0  1.400000e+12  -71.000000
# 14000029101        18.0     140000291.0     1.0  1.400000e+12  138.333333
# ...                 ...             ...     ...           ...         ...
# 18025693601    126856.0     180256936.0     1.0  1.800000e+12   -2.000000
# 18025694001    126861.0     180256940.0     1.0  1.800000e+12  -31.000000
# 18025694002    126866.0     180256940.0     2.0  1.800000e+12   91.000000
# 18025694101    126869.5     180256941.0     1.0  1.800000e+12 -387.500000
# 18025694102    126872.0     180256941.0     2.0  1.800000e+12 -165.000000
#
#              TRIPNO  O_PURPOSE  O_ACTIVITY  MPO_O_ACTIVITY  O_STATE_FIPS  ...  \
# PERSON_ID                                                                 ...
# 14000027101     3.0   3.000000    3.000000            -9.0          24.0  ...
# 14000027103     1.5  50.000000    1.500000            -9.0          24.0  ...
# 14000028001     3.0   3.600000    4.400000            -9.0          24.0  ...
# 14000028401     3.0   7.000000    9.200000            -9.0          24.0  ...
# 14000029101     2.0   4.333333    4.000000            -9.0          24.0  ...
# ...             ...        ...         ...             ...           ...  ...
# 18025693601     3.0   4.800000    6.600000             9.6          24.0  ...
# 18025694001     3.0   4.400000    6.800000           206.2          51.0  ...
# 18025694002     3.0   4.800000    5.200000             8.8          51.0  ...
# 18025694101     1.5   2.500000    4.000000             6.5          24.0  ...
# 18025694102     2.0   2.333333    2.666667             5.0          24.0  ...
#
#              MPO_TD_SHOP_TIME  PERSON_TRIPCOUNT  WALK_BIKE_LOOP_TRIPS  \
# PERSON_ID
# 14000027101              -9.0               5.0                  -9.0
# 14000027103              -9.0               2.0                  -9.0
# 14000028001              -9.0               5.0                  -9.0
# 14000028401              -9.0               5.0                  -9.0
# 14000029101              -9.0               3.0                  -9.0
# ...                       ...               ...                   ...
# 18025693601              30.0               5.0                   1.0
# 18025694001              15.0               5.0                   0.0
# 18025694002               0.0               5.0                   0.0
# 18025694101               0.0               2.0                   0.0
# 18025694102               0.0               3.0                   0.0
#
#                WTPERFIN  WWM_WTPERFIN  AGE_IMP  GENDER_IMP  RACEETHNICITY_IMP  \
# PERSON_ID
# 14000027101  136.460113         153.0     -9.0        -9.0               -9.0
# 14000027103  136.460113         152.0     -9.0        -9.0               -9.0
# 14000028001  131.745870         143.0     -9.0        -9.0               -9.0
# 14000028401   91.688043          92.0     -9.0        -9.0               -9.0
# 14000029101   88.698225         100.0     -9.0        -9.0               -9.0
# ...                 ...           ...      ...         ...                ...
# 18025693601  101.000000         105.0      1.0         0.0                1.0
# 18025694001  139.000000         140.0      0.0         0.0                0.0
# 18025694002  139.000000         141.0      0.0         0.0                0.0
# 18025694101  157.000000         163.0      0.0         0.0                1.0
# 18025694102  157.000000         171.0      0.0         0.0                1.0
#
#              MPO_RACEETHNICITY_IMP  DISABILITY_IMP
# PERSON_ID
# 14000027101                   -9.0            -9.0
# 14000027103                   -9.0            -9.0
# 14000028001                   -9.0            -9.0
# 14000028401                   -9.0            -9.0
# 14000029101                   -9.0            -9.0
# ...                            ...             ...
# 18025693601                    1.0             1.0
# 18025694001                    0.0             0.0
# 18025694002                    0.0             0.0
# 18025694101                    1.0             0.0
# 18025694102                    1.0             0.0
#
# [32923 rows x 123 columns]

# %%
my_list = list(aff)
my_list
# Out:
# ['Unnamed: 0',
#  'HOUSEHOLD_ID_x',
#  'PERSNO',
#  'TRIPID',
#  'Dwelltime',
#  'TRIPNO',
#  'O_PURPOSE',
#  'O_ACTIVITY',
#  'MPO_O_ACTIVITY',
#  'O_STATE_FIPS',
#  'O_STATE_COUNTY_FIPS',
#  'O_TRACT_FIPS',
#  'O_TPB_TAZ',
#  'O_BMC_TAZ',
#  'D_PURPOSE',
#  'D_ACTIVITY',
#  'MPO_D_ACTIVITY',
#  'D_STATE_FIPS',
#  'D_STATE_COUNTY_FIPS',
#  'D_TRACT_FIPS',
#  'D_TPB_TAZ',
#  'D_BMC_TAZ',
#  'TRAVEL_MODE',
#  'TRANSIT_ACCESS_MODE',
#  'TRANSIT_EGRESS_MODE',
#  'TRAVELERS_TOTAL',
#  'TRAVELERS_HH',
#  'TRAVELERS_NONHH',
#  'HH_MEMBER1',
#  'HH_MEMBER2',
#  'HH_MEMBER3',
#  'HH_MEMBER4',
#  'HH_MEMBER5',
#  'HH_MEMBER6',
#  'HH_MEMBER7',
#  'HH_MEMBER8',
#  'MODE_HH_VEHICLE',
#  'MPO_MODE_OTHER_VEHICLE',
#  'VEHICLE_OCCUPANCY',
#  'PARK_LOC',
#  'MPO_PARK_LOC',
#  'PARK_PAY',
#  'MPO_PARK_PAY',
#  'SUBWAY_USED',
#  'SUBWAY_PAY',
#  'SUBWAY_STATION_BOARD',
#  'SUBWAY_ACCESS_MODE',
#  'SUBWAY_STATION_EXIT',
#  'SUBWAY_EGRESS_MODE',
#  'HOV_USED',
#  'TOLL_ROAD_USED',
#  'DISTANCE',
#  'REPORTED_TRAVEL_TIME',
#  'WTTRDFIN',
#  'WWM_WTTRDFIN',
#  'HOUSEHOLD_ID_y',
#  'AGE',
#  'AGE_GROUP',
#  'GENDER',
#  'RACEETHNICITY',
#  'MPO_RACEETHNICITY',
#  'RACEETHNICITY_HISPANIC',
#  'MPO_RACEETHNICITY_HISPANIC',
#  'LICENSE',
#  'DISABILITY',
#  'SMARTPHONE',
#  'EMPLOYMENT_STATUS',
#  'MPO_EMPLOYMENT_STATUS',
#  'MPO_UNEMPLOYMENT_STATUS',
#  'JOBS_COUNT',
#  'MPO_J1_EMPLOYER_TYPE',
#  'J1_WORKPLACE_LOC',
#  'WORK_STATE_FIPS',
#  'WORK_STATE_COUNTY_FIPS',
#  'WORK_TRACT_FIPS',
#  'WORK_TPB_TAZ',
#  'WORK_BMC_TAZ',
#  'J1_COMMUTE_FREQ',
#  'J1_COMMUTE_MODE',
#  'MPO_J1_COMMUTE_MODE',
#  'J1_TELECOMMUTE',
#  'MPO_J1_TELECOMMUTE',
#  'J1_TELECOMMUTE_DAYS',
#  'MPO_J1_TELECOMMUTE_DAYS',
#  'J1_BENEFITS_FREE_PARKING',
#  'J1_BENEFITS_PARKING',
#  'J1_BENEFITS_TRANSIT',
#  'J1_BENEFITS_CARPOOL',
#  'J1_BENEFITS_WALKING_BIKING',
#  'J1_BENEFITS_EV_CHARGING',
#  'J1_BENEFITS_BICYCLE_PARKING',
#  'J1_BENEFITS_NONE',
#  'STUDENT_STATUS',
#  'SCHOOL_TYPE',
#  'MPO_SCHOOL_TYPE',
#  'SCHOOL_STATE_FIPS',
#  'SCHOOL_STATE_COUNTY_FIPS',
#  'SCHOOL_TRACT_FIPS',
#  'SCHOOL_TPB_TAZ',
#  'SCHOOL_BMC_TAZ',
#  'SCHOOL_FREQ',
#  'SCHOOL_MODE',
#  'MPO_SCHOOL_MODE',
#  'VOLUNTEER_STATUS',
#  'TRIPS_YESNO',
#  'NO_TRAVEL',
#  'MPO_NO_TRAVEL',
#  'TD_PAIDPARK',
#  'TD_HOV',
#  'TD_TOLL',
#  'TD_TELECOMMUTE_TIME',
#  'MPO_TD_TELECOMMUTE_TIME',
#  'TD_SHOP_TIME',
#  'MPO_TD_SHOP_TIME',
#  'PERSON_TRIPCOUNT',
#  'WALK_BIKE_LOOP_TRIPS',
#  'WTPERFIN',
#  'WWM_WTPERFIN',
#  'AGE_IMP',
#  'GENDER_IMP',
#  'RACEETHNICITY_IMP',
#  'MPO_RACEETHNICITY_IMP',
#  'DISABILITY_IMP']

# %%
#df1["WHYTO"].replace({1: 'Home', 2: 'Home', 3:'Stop', 4:'Stop', 5: 'Stop', 6:'Stop', 7:'Stop', 8:'Stop', 9:'Stop', 10:'Stop', 11:'Stop', 12:'Stop',13:'Stop',14:'Stop',15:'Stop',16:'Stop',17:'Stop',18:'Stop',19:'Stop',97:'Stop',-7 :'Stop', -8 : 'Stop', 97:'Stop',-9:'Stop'}, inplace=True)
#df1["D_PURPOSE"].replace({1: 'Home', 2: 'Work', 3:'Work', 4:'Shop', 7:'School', 8:'School', 9:'Other', 11:'Other',13:'Other',16:'Publictransit',17:'Publictransit',19:'Airport',77:'Other',99 :'Other',-9:'Other'}, inplace=True)
aff["RACEETHNICITY"].replace({1:"Hispanic", 2: "Black", 3:'Asian', 4:'White',5:'Others', -9:'Others'},  inplace = True)
#df["TRAVEL_MODE"].replace({1: 'Walk', 2: 'Bike', 3:'Bike', 4:'Car', 5:'Car', 6:'School bus', 7:'rail', 8:'Bus', 9:'Bus',10:'Para transit',11:'Taxi',12:'Taxi',13:'Air',14:'Water',15:'Others'}, inplace=True)
aff["TRAVEL_MODE"].replace({1: 'Walk', 2: 'Bike', 3:'Bike', 4:'Private car', 5:'Private car', 6:'School bus', 7:'Public transit', 8:'Public transit', 9:'Rideshare/Private Bus',10:'Rideshare/Private Bus',11:'Rideshare/Private Bus',12:'Rideshare/Private Bus',13:'Others',14:'Others',15:'Others'}, inplace=True)
aff["LICENSE"].replace({1: 'With License', 2: 'No License',-9:'No response'}, inplace=True)
aff["DISABILITY"].replace({1: 'Disabled', 2: 'Not disabled',-9:'No response'}, inplace=True)
aff["EMPLOYMENT_STATUS"].replace({0: 'Employed',1: 'Retired', 2: 'Employed', 3:'Unemployed',4:'Unemployed', 5:'Unemployed', 6:'Student',7:'Unemployed',-9:'Unemployed'}, inplace=True)
aff["GENDER"].replace({1: 'Female', 2: 'Male',-9:'No response'}, inplace=True)


aff
# Out:
#              Unnamed: 0  HOUSEHOLD_ID_x  PERSNO        TRIPID   Dwelltime  \
# PERSON_ID
# 14000027101         2.0     140000271.0     1.0  1.400000e+12  -29.200000
# 14000027103         5.5     140000271.0     3.0  1.400000e+12  -78.000000
# 14000028001         9.0     140000280.0     1.0  1.400000e+12   25.600000
# 14000028401        14.0     140000284.0     1.0  1.400000e+12  -71.000000
# 14000029101        18.0     140000291.0     1.0  1.400000e+12  138.333333
# ...                 ...             ...     ...           ...         ...
# 18025693601    126856.0     180256936.0     1.0  1.800000e+12   -2.000000
# 18025694001    126861.0     180256940.0     1.0  1.800000e+12  -31.000000
# 18025694002    126866.0     180256940.0     2.0  1.800000e+12   91.000000
# 18025694101    126869.5     180256941.0     1.0  1.800000e+12 -387.500000
# 18025694102    126872.0     180256941.0     2.0  1.800000e+12 -165.000000
#
#              TRIPNO  O_PURPOSE  O_ACTIVITY  MPO_O_ACTIVITY  O_STATE_FIPS  ...  \
# PERSON_ID                                                                 ...
# 14000027101     3.0   3.000000    3.000000            -9.0          24.0  ...
# 14000027103     1.5  50.000000    1.500000            -9.0          24.0  ...
# 14000028001     3.0   3.600000    4.400000            -9.0          24.0  ...
# 14000028401     3.0   7.000000    9.200000            -9.0          24.0  ...
# 14000029101     2.0   4.333333    4.000000            -9.0          24.0  ...
# ...             ...        ...         ...             ...           ...  ...
# 18025693601     3.0   4.800000    6.600000             9.6          24.0  ...
# 18025694001     3.0   4.400000    6.800000           206.2          51.0  ...
# 18025694002     3.0   4.800000    5.200000             8.8          51.0  ...
# 18025694101     1.5   2.500000    4.000000             6.5          24.0  ...
# 18025694102     2.0   2.333333    2.666667             5.0          24.0  ...
#
#              MPO_TD_SHOP_TIME  PERSON_TRIPCOUNT  WALK_BIKE_LOOP_TRIPS  \
# PERSON_ID
# 14000027101              -9.0               5.0                  -9.0
# 14000027103              -9.0               2.0                  -9.0
# 14000028001              -9.0               5.0                  -9.0
# 14000028401              -9.0               5.0                  -9.0
# 14000029101              -9.0               3.0                  -9.0
# ...                       ...               ...                   ...
# 18025693601              30.0               5.0                   1.0
# 18025694001              15.0               5.0                   0.0
# 18025694002               0.0               5.0                   0.0
# 18025694101               0.0               2.0                   0.0
# 18025694102               0.0               3.0                   0.0
#
#                WTPERFIN  WWM_WTPERFIN  AGE_IMP  GENDER_IMP  RACEETHNICITY_IMP  \
# PERSON_ID
# 14000027101  136.460113         153.0     -9.0        -9.0               -9.0
# 14000027103  136.460113         152.0     -9.0        -9.0               -9.0
# 14000028001  131.745870         143.0     -9.0        -9.0               -9.0
# 14000028401   91.688043          92.0     -9.0        -9.0               -9.0
# 14000029101   88.698225         100.0     -9.0        -9.0               -9.0
# ...                 ...           ...      ...         ...                ...
# 18025693601  101.000000         105.0      1.0         0.0                1.0
# 18025694001  139.000000         140.0      0.0         0.0                0.0
# 18025694002  139.000000         141.0      0.0         0.0                0.0
# 18025694101  157.000000         163.0      0.0         0.0                1.0
# 18025694102  157.000000         171.0      0.0         0.0                1.0
#
#              MPO_RACEETHNICITY_IMP  DISABILITY_IMP
# PERSON_ID
# 14000027101                   -9.0            -9.0
# 14000027103                   -9.0            -9.0
# 14000028001                   -9.0            -9.0
# 14000028401                   -9.0            -9.0
# 14000029101                   -9.0            -9.0
# ...                            ...             ...
# 18025693601                    1.0             1.0
# 18025694001                    0.0             0.0
# 18025694002                    0.0             0.0
# 18025694101                    1.0             0.0
# 18025694102                    1.0             0.0
#
# [32923 rows x 123 columns]

# %%
category = pd.cut(aff.AGE,bins=[0,5,17,65,99],labels=['Toddler/baby','Child','Adult','Elderly'])
aff.insert(5,'Ageclass',category)

aff
# Out:
#              Unnamed: 0  HOUSEHOLD_ID_x  PERSNO        TRIPID   Dwelltime  \
# PERSON_ID
# 14000027101         2.0     140000271.0     1.0  1.400000e+12  -29.200000
# 14000027103         5.5     140000271.0     3.0  1.400000e+12  -78.000000
# 14000028001         9.0     140000280.0     1.0  1.400000e+12   25.600000
# 14000028401        14.0     140000284.0     1.0  1.400000e+12  -71.000000
# 14000029101        18.0     140000291.0     1.0  1.400000e+12  138.333333
# ...                 ...             ...     ...           ...         ...
# 18025693601    126856.0     180256936.0     1.0  1.800000e+12   -2.000000
# 18025694001    126861.0     180256940.0     1.0  1.800000e+12  -31.000000
# 18025694002    126866.0     180256940.0     2.0  1.800000e+12   91.000000
# 18025694101    126869.5     180256941.0     1.0  1.800000e+12 -387.500000
# 18025694102    126872.0     180256941.0     2.0  1.800000e+12 -165.000000
#
#             Ageclass  TRIPNO  O_PURPOSE  O_ACTIVITY  MPO_O_ACTIVITY  ...  \
# PERSON_ID                                                            ...
# 14000027101    Adult     3.0   3.000000    3.000000            -9.0  ...
# 14000027103    Adult     1.5  50.000000    1.500000            -9.0  ...
# 14000028001  Elderly     3.0   3.600000    4.400000            -9.0  ...
# 14000028401  Elderly     3.0   7.000000    9.200000            -9.0  ...
# 14000029101    Adult     2.0   4.333333    4.000000            -9.0  ...
# ...              ...     ...        ...         ...             ...  ...
# 18025693601    Adult     3.0   4.800000    6.600000             9.6  ...
# 18025694001  Elderly     3.0   4.400000    6.800000           206.2  ...
# 18025694002  Elderly     3.0   4.800000    5.200000             8.8  ...
# 18025694101    Adult     1.5   2.500000    4.000000             6.5  ...
# 18025694102    Adult     2.0   2.333333    2.666667             5.0  ...
#
#              MPO_TD_SHOP_TIME  PERSON_TRIPCOUNT  WALK_BIKE_LOOP_TRIPS  \
# PERSON_ID
# 14000027101              -9.0               5.0                  -9.0
# 14000027103              -9.0               2.0                  -9.0
# 14000028001              -9.0               5.0                  -9.0
# 14000028401              -9.0               5.0                  -9.0
# 14000029101              -9.0               3.0                  -9.0
# ...                       ...               ...                   ...
# 18025693601              30.0               5.0                   1.0
# 18025694001              15.0               5.0                   0.0
# 18025694002               0.0               5.0                   0.0
# 18025694101               0.0               2.0                   0.0
# 18025694102               0.0               3.0                   0.0
#
#                WTPERFIN  WWM_WTPERFIN  AGE_IMP  GENDER_IMP  RACEETHNICITY_IMP  \
# PERSON_ID
# 14000027101  136.460113         153.0     -9.0        -9.0               -9.0
# 14000027103  136.460113         152.0     -9.0        -9.0               -9.0
# 14000028001  131.745870         143.0     -9.0        -9.0               -9.0
# 14000028401   91.688043          92.0     -9.0        -9.0               -9.0
# 14000029101   88.698225         100.0     -9.0        -9.0               -9.0
# ...                 ...           ...      ...         ...                ...
# 18025693601  101.000000         105.0      1.0         0.0                1.0
# 18025694001  139.000000         140.0      0.0         0.0                0.0
# 18025694002  139.000000         141.0      0.0         0.0                0.0
# 18025694101  157.000000         163.0      0.0         0.0                1.0
# 18025694102  157.000000         171.0      0.0         0.0                1.0
#
#              MPO_RACEETHNICITY_IMP  DISABILITY_IMP
# PERSON_ID
# 14000027101                   -9.0            -9.0
# 14000027103                   -9.0            -9.0
# 14000028001                   -9.0            -9.0
# 14000028401                   -9.0            -9.0
# 14000029101                   -9.0            -9.0
# ...                            ...             ...
# 18025693601                    1.0             1.0
# 18025694001                    0.0             0.0
# 18025694002                    0.0             0.0
# 18025694101                    1.0             0.0
# 18025694102                    1.0             0.0
#
# [32923 rows x 124 columns]

# %%
# locate and load file to Read 
df = pd.read_csv('semifinalHBO.csv')
df
# Out:
#        Unnamed: 0    PERSON_ID           O_PURPOSE_x O_PURPOSE_y  \
# 0               0  14000027101  HomeWorkStopStopWork        Home
# 1               1  14000027103              HomeStop        Home
# 2               2  14000028001  HomeWorkHomeStopStop        Home
# 3               3  14000029101          HomeWorkStop        Home
# 4               4  14000029102              HomeStop        Home
# ...           ...          ...                   ...         ...
# 31734       31734  18025693601  HomeStopHomeStopStop        Home
# 31735       31735  18025694001  HomeStopStopStopStop        Home
# 31736       31736  18025694002  HomeStopStopHomeStop        Home
# 31737       31737  18025694101              HomeStop        Home
# 31738       31738  18025694102          HomeWorkStop        Home
#
#                 Home_Based_Tour  Expected_Output
# 0      HomeWorkStopStopWorkHome             True
# 1                  HomeStopHome            False
# 2      HomeWorkHomeStopStopHome             True
# 3              HomeWorkStopHome             True
# 4                  HomeStopHome            False
# ...                         ...              ...
# 31734  HomeStopHomeStopStopHome            False
# 31735  HomeStopStopStopStopHome            False
# 31736  HomeStopStopHomeStopHome            False
# 31737              HomeStopHome            False
# 31738          HomeWorkStopHome             True
#
# [31739 rows x 6 columns]

# %%
dff=(pd.merge(df, aff, on='PERSON_ID'))
dff
# Out:
#        Unnamed: 0_x    PERSON_ID           O_PURPOSE_x O_PURPOSE_y  \
# 0                 0  14000027101  HomeWorkStopStopWork        Home
# 1                 1  14000027103              HomeStop        Home
# 2                 2  14000028001  HomeWorkHomeStopStop        Home
# 3                 3  14000029101          HomeWorkStop        Home
# 4                 4  14000029102              HomeStop        Home
# ...             ...          ...                   ...         ...
# 31734         31734  18025693601  HomeStopHomeStopStop        Home
# 31735         31735  18025694001  HomeStopStopStopStop        Home
# 31736         31736  18025694002  HomeStopStopHomeStop        Home
# 31737         31737  18025694101              HomeStop        Home
# 31738         31738  18025694102          HomeWorkStop        Home
#
#                 Home_Based_Tour  Expected_Output  Unnamed: 0_y  \
# 0      HomeWorkStopStopWorkHome             True           2.0
# 1                  HomeStopHome            False           5.5
# 2      HomeWorkHomeStopStopHome             True           9.0
# 3              HomeWorkStopHome             True          18.0
# 4                  HomeStopHome            False          20.5
# ...                         ...              ...           ...
# 31734  HomeStopHomeStopStopHome            False      126856.0
# 31735  HomeStopStopStopStopHome            False      126861.0
# 31736  HomeStopStopHomeStopHome            False      126866.0
# 31737              HomeStopHome            False      126869.5
# 31738          HomeWorkStopHome             True      126872.0
#
#        HOUSEHOLD_ID_x  PERSNO        TRIPID  ...  MPO_TD_SHOP_TIME  \
# 0         140000271.0     1.0  1.400000e+12  ...              -9.0
# 1         140000271.0     3.0  1.400000e+12  ...              -9.0
# 2         140000280.0     1.0  1.400000e+12  ...              -9.0
# 3         140000291.0     1.0  1.400000e+12  ...              -9.0
# 4         140000291.0     2.0  1.400000e+12  ...              -9.0
# ...               ...     ...           ...  ...               ...
# 31734     180256936.0     1.0  1.800000e+12  ...              30.0
# 31735     180256940.0     1.0  1.800000e+12  ...              15.0
# 31736     180256940.0     2.0  1.800000e+12  ...               0.0
# 31737     180256941.0     1.0  1.800000e+12  ...               0.0
# 31738     180256941.0     2.0  1.800000e+12  ...               0.0
#
#       PERSON_TRIPCOUNT  WALK_BIKE_LOOP_TRIPS    WTPERFIN  WWM_WTPERFIN  \
# 0                  5.0                  -9.0  136.460113         153.0
# 1                  2.0                  -9.0  136.460113         152.0
# 2                  5.0                  -9.0  131.745870         143.0
# 3                  3.0                  -9.0   88.698225         100.0
# 4                  2.0                  -9.0   88.698225          88.0
# ...                ...                   ...         ...           ...
# 31734              5.0                   1.0  101.000000         105.0
# 31735              5.0                   0.0  139.000000         140.0
# 31736              5.0                   0.0  139.000000         141.0
# 31737              2.0                   0.0  157.000000         163.0
# 31738              3.0                   0.0  157.000000         171.0
#
#        AGE_IMP  GENDER_IMP  RACEETHNICITY_IMP  MPO_RACEETHNICITY_IMP  \
# 0         -9.0        -9.0               -9.0                   -9.0
# 1         -9.0        -9.0               -9.0                   -9.0
# 2         -9.0        -9.0               -9.0                   -9.0
# 3         -9.0        -9.0               -9.0                   -9.0
# 4         -9.0        -9.0               -9.0                   -9.0
# ...        ...         ...                ...                    ...
# 31734      1.0         0.0                1.0                    1.0
# 31735      0.0         0.0                0.0                    0.0
# 31736      0.0         0.0                0.0                    0.0
# 31737      0.0         0.0                1.0                    1.0
# 31738      0.0         0.0                1.0                    1.0
#
#        DISABILITY_IMP
# 0                -9.0
# 1                -9.0
# 2                -9.0
# 3                -9.0
# 4                -9.0
# ...               ...
# 31734             1.0
# 31735             0.0
# 31736             0.0
# 31737             0.0
# 31738             0.0
#
# [31739 rows x 130 columns]

# %%
dff=dff.applymap(str)
dff
# Out:
#       Unnamed: 0_x    PERSON_ID           O_PURPOSE_x O_PURPOSE_y  \
# 0                0  14000027101  HomeWorkStopStopWork        Home
# 1                1  14000027103              HomeStop        Home
# 2                2  14000028001  HomeWorkHomeStopStop        Home
# 3                3  14000029101          HomeWorkStop        Home
# 4                4  14000029102              HomeStop        Home
# ...            ...          ...                   ...         ...
# 31734        31734  18025693601  HomeStopHomeStopStop        Home
# 31735        31735  18025694001  HomeStopStopStopStop        Home
# 31736        31736  18025694002  HomeStopStopHomeStop        Home
# 31737        31737  18025694101              HomeStop        Home
# 31738        31738  18025694102          HomeWorkStop        Home
#
#                 Home_Based_Tour Expected_Output Unnamed: 0_y HOUSEHOLD_ID_x  \
# 0      HomeWorkStopStopWorkHome            True          2.0    140000271.0
# 1                  HomeStopHome           False          5.5    140000271.0
# 2      HomeWorkHomeStopStopHome            True          9.0    140000280.0
# 3              HomeWorkStopHome            True         18.0    140000291.0
# 4                  HomeStopHome           False         20.5    140000291.0
# ...                         ...             ...          ...            ...
# 31734  HomeStopHomeStopStopHome           False     126856.0    180256936.0
# 31735  HomeStopStopStopStopHome           False     126861.0    180256940.0
# 31736  HomeStopStopHomeStopHome           False     126866.0    180256940.0
# 31737              HomeStopHome           False     126869.5    180256941.0
# 31738          HomeWorkStopHome            True     126872.0    180256941.0
#
#       PERSNO           TRIPID  ... MPO_TD_SHOP_TIME PERSON_TRIPCOUNT  \
# 0        1.0  1400000000000.0  ...             -9.0              5.0
# 1        3.0  1400000000000.0  ...             -9.0              2.0
# 2        1.0  1400000000000.0  ...             -9.0              5.0
# 3        1.0  1400000000000.0  ...             -9.0              3.0
# 4        2.0  1400000000000.0  ...             -9.0              2.0
# ...      ...              ...  ...              ...              ...
# 31734    1.0  1800000000000.0  ...             30.0              5.0
# 31735    1.0  1800000000000.0  ...             15.0              5.0
# 31736    2.0  1800000000000.0  ...              0.0              5.0
# 31737    1.0  1800000000000.0  ...              0.0              2.0
# 31738    2.0  1800000000000.0  ...              0.0              3.0
#
#       WALK_BIKE_LOOP_TRIPS     WTPERFIN WWM_WTPERFIN AGE_IMP GENDER_IMP  \
# 0                     -9.0  136.4601132        153.0    -9.0       -9.0
# 1                     -9.0  136.4601132        152.0    -9.0       -9.0
# 2                     -9.0  131.7458696        143.0    -9.0       -9.0
# 3                     -9.0  88.69822541        100.0    -9.0       -9.0
# 4                     -9.0  88.69822541         88.0    -9.0       -9.0
# ...                    ...          ...          ...     ...        ...
# 31734                  1.0        101.0        105.0     1.0        0.0
# 31735                  0.0        139.0        140.0     0.0        0.0
# 31736                  0.0        139.0        141.0     0.0        0.0
# 31737                  0.0        157.0        163.0     0.0        0.0
# 31738                  0.0        157.0        171.0     0.0        0.0
#
#       RACEETHNICITY_IMP MPO_RACEETHNICITY_IMP DISABILITY_IMP
# 0                  -9.0                  -9.0           -9.0
# 1                  -9.0                  -9.0           -9.0
# 2                  -9.0                  -9.0           -9.0
# 3                  -9.0                  -9.0           -9.0
# 4                  -9.0                  -9.0           -9.0
# ...                 ...                   ...            ...
# 31734               1.0                   1.0            1.0
# 31735               0.0                   0.0            0.0
# 31736               0.0                   0.0            0.0
# 31737               1.0                   1.0            0.0
# 31738               1.0                   1.0            0.0
#
# [31739 rows x 130 columns]

# %% [raw]
# #df1["WHYTO"].replace({1: 'Home', 2: 'Home', 3:'Stop', 4:'Stop', 5: 'Stop', 6:'Stop', 7:'Stop', 8:'Stop', 9:'Stop', 10:'Stop', 11:'Stop', 12:'Stop',13:'Stop',14:'Stop',15:'Stop',16:'Stop',17:'Stop',18:'Stop',19:'Stop',97:'Stop',-7 :'Stop', -8 : 'Stop', 97:'Stop',-9:'Stop'}, inplace=True)
# #df1["D_PURPOSE"].replace({1: 'Home', 2: 'Work', 3:'Work', 4:'Shop', 7:'School', 8:'School', 9:'Other', 11:'Other',13:'Other',16:'Publictransit',17:'Publictransit',19:'Airport',77:'Other',99 :'Other',-9:'Other'}, inplace=True)
# dff["RACEETHNICITY"].replace({1:"Hispanic", 2: "Black", 3:'Asian', 4:'White',5:'Others', -9:'Others'},  inplace = True)
# #df["TRAVEL_MODE"].replace({1: 'Walk', 2: 'Bike', 3:'Bike', 4:'Car', 5:'Car', 6:'School bus', 7:'rail', 8:'Bus', 9:'Bus',10:'Para transit',11:'Taxi',12:'Taxi',13:'Air',14:'Water',15:'Others'}, inplace=True)
# dff["TRAVEL_MODE"].replace({1: 'Walk', 2: 'Bike', 3:'Bike', 4:'Private car', 5:'Private car', 6:'School bus', 7:'Public transit', 8:'Public transit', 9:'Rideshare/Private Bus',10:'Rideshare/Private Bus',11:'Rideshare/Private Bus',12:'Rideshare/Private Bus',13:'Others',14:'Others',15:'Others'}, inplace=True)
# #dff["D_PURPOSE"].replace({1: 'Home', 2: 'Stop', 3:'Stop', 4:'Stop', 7:'Stop', 8:'Stop', 9:'Stop', 11:'Stop',13:'Stop',16:'Stop',17:'Stop',18:'Stop',19:'Stop',77:'Stop',99 :'Stop',-9:'Stop'}, inplace=True)
# dff

# %% [markdown]
# #home based work trips
# df1=dff.loc[dff.Goingtowork=='True', :]
# df1.head(30)

# %% [markdown]
# # Home based work trips

# %%
#home based Other trips 
df1=dff.loc[dff.Expected_Output=='True', :]
df1
# Out:
#       Unnamed: 0_x    PERSON_ID                       O_PURPOSE_x O_PURPOSE_y  \
# 0                0  14000027101              HomeWorkStopStopWork        Home
# 2                2  14000028001              HomeWorkHomeStopStop        Home
# 3                3  14000029101                      HomeWorkStop        Home
# 7                7  14000031601              HomeWorkHomeStopHome        Home
# 8                8  14000031602  HomeWorkWorkWorkWorkWorkHomeStop        Home
# ...            ...          ...                               ...         ...
# 31728        31728  18025682902                  HomeStopWorkStop        Home
# 31730        31730  18025684801          HomeWorkWorkWorkHomeStop        Home
# 31731        31731  18025686801                          HomeWork        Home
# 31732        31732  18025686802                          HomeWork        Home
# 31738        31738  18025694102                      HomeWorkStop        Home
#
#                             Home_Based_Tour Expected_Output Unnamed: 0_y  \
# 0                  HomeWorkStopStopWorkHome            True          2.0
# 2                  HomeWorkHomeStopStopHome            True          9.0
# 3                          HomeWorkStopHome            True         18.0
# 7                  HomeWorkHomeStopHomeHome            True         38.0
# 8      HomeWorkWorkWorkWorkWorkHomeStopHome            True         44.5
# ...                                     ...             ...          ...
# 31728                  HomeStopWorkStopHome            True     126828.5
# 31730          HomeWorkWorkWorkHomeStopHome            True     126835.5
# 31731                          HomeWorkHome            True     126839.5
# 31732                          HomeWorkHome            True     126841.5
# 31738                      HomeWorkStopHome            True     126872.0
#
#       HOUSEHOLD_ID_x PERSNO           TRIPID  ... MPO_TD_SHOP_TIME  \
# 0        140000271.0    1.0  1400000000000.0  ...             -9.0
# 2        140000280.0    1.0  1400000000000.0  ...             -9.0
# 3        140000291.0    1.0  1400000000000.0  ...             -9.0
# 7        140000316.0    1.0  1400000000000.0  ...             -9.0
# 8        140000316.0    2.0  1400000000000.0  ...             -9.0
# ...              ...    ...              ...  ...              ...
# 31728    180256829.0    2.0  1800000000000.0  ...              0.0
# 31730    180256848.0    1.0  1800000000000.0  ...              0.0
# 31731    180256868.0    1.0  1800000000000.0  ...             75.0
# 31732    180256868.0    2.0  1800000000000.0  ...             60.0
# 31738    180256941.0    2.0  1800000000000.0  ...              0.0
#
#       PERSON_TRIPCOUNT WALK_BIKE_LOOP_TRIPS     WTPERFIN WWM_WTPERFIN AGE_IMP  \
# 0                  5.0                 -9.0  136.4601132        153.0    -9.0
# 2                  5.0                 -9.0  131.7458696        143.0    -9.0
# 3                  3.0                 -9.0  88.69822541        100.0    -9.0
# 7                  5.0                 -9.0  58.04967412         65.0    -9.0
# 8                  8.0                 -9.0  58.04967412         65.0    -9.0
# ...                ...                  ...          ...          ...     ...
# 31728              4.0                  0.0        245.0        282.0     0.0
# 31730              6.0                  0.0         95.0         94.0     0.0
# 31731              2.0                  0.0         99.0        120.0     0.0
# 31732              2.0                  0.0         99.0         91.0     0.0
# 31738              3.0                  0.0        157.0        171.0     0.0
#
#       GENDER_IMP RACEETHNICITY_IMP MPO_RACEETHNICITY_IMP DISABILITY_IMP
# 0           -9.0              -9.0                  -9.0           -9.0
# 2           -9.0              -9.0                  -9.0           -9.0
# 3           -9.0              -9.0                  -9.0           -9.0
# 7           -9.0              -9.0                  -9.0           -9.0
# 8           -9.0              -9.0                  -9.0           -9.0
# ...          ...               ...                   ...            ...
# 31728        0.0               0.0                   0.0            0.0
# 31730        0.0               0.0                   0.0            0.0
# 31731        0.0               0.0                   0.0            0.0
# 31732        0.0               0.0                   0.0            0.0
# 31738        0.0               1.0                   1.0            0.0
#
# [14810 rows x 130 columns]

# %%
#analyzing Home Based WOrk trips 
df11=df1['Home_Based_Tour'].value_counts(normalize=True) * 100
df11
# Out:
# HomeWorkHome                                                    32.201215
# HomeWorkStopHome                                                11.796084
# HomeWorkHomeStopHome                                             6.164754
# HomeWorkStopWorkHome                                             4.037812
# HomeWorkStopStopHome                                             3.490885
#                                                                   ...
# HomeStopStopStopHomeStopWorkStopWorkStopStopStopStopHome         0.006752
# HomeStopStopStopHomeStopHomeStopHomeStopHomeWorkHomeStopHome     0.006752
# HomeStopHomeStopWorkStopWorkHomeStopHome                         0.006752
# HomeWorkWorkStopStopWorkHomeStopStopHome                         0.006752
# HomeWorkWorkWorkWorkStopWorkStopWorkWorkHome                     0.006752
# Name: Home_Based_Tour, Length: 880, dtype: float64

# %%
df11.to_csv('HBW tour.csv')

# %%
#analyzing Home Based WOrk trips 
df111=df1['RACEETHNICITY'].value_counts(normalize=True) * 100
df111
# Out:
# White       69.547603
# Black       13.416610
# Asian        8.345712
# Hispanic     5.293720
# Others       3.396354
# Name: RACEETHNICITY, dtype: float64

# %%
#analyzing Home Based WOrk trips 
#df112=df1['TRAVEL_MODE'].value_counts(normalize=True) * 100
#df112
# Out:
# Private car           65.523295
# Public transit         7.954085
# Bike                   2.916948
# Walk                   1.809588
# 4.5                    1.748818
#                         ...
# 3.357142857142857      0.006752
# 1.7142857142857142     0.006752
# 4.235294117647059      0.006752
# 3.3636363636363638     0.006752
# 6.454545454545454      0.006752
# Name: TRAVEL_MODE, Length: 220, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df113=df1['GENDER'].value_counts(normalize=True) * 100
df113
# Out:
# Male      50.378123
# Female    49.621877
# Name: GENDER, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df114=df1['LICENSE'].value_counts(normalize=True) * 100
df114
# Out:
# With License    96.772451
# No License       3.227549
# Name: LICENSE, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df115=df1['DISABILITY'].value_counts(normalize=True) * 100
df115
# Out:
# Not disabled    98.453747
# Disabled         1.444970
# No response      0.101283
# Name: DISABILITY, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df116=df1['EMPLOYMENT_STATUS'].value_counts(normalize=True) * 100
df116
# Out:
# Employed      97.731263
# Unemployed     0.958812
# Retired        0.898042
# Student        0.411884
# Name: EMPLOYMENT_STATUS, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df117=df1['Ageclass'].value_counts(normalize=True) * 100
df117
# Out:
# Adult           93.673194
# Elderly          5.725861
# Child            0.486158
# Toddler/baby     0.094531
# nan              0.020257
# Name: Ageclass, dtype: float64

# %% [markdown]
# # Home based other tour

# %%
#home based Other trips 
df2=dff.loc[dff.Expected_Output=='False', :]
df2
# Out:
#       Unnamed: 0_x    PERSON_ID  \
# 1                1  14000027103
# 4                4  14000029102
# 5                5  14000029901
# 6                6  14000030901
# 9                9  14000032401
# ...            ...          ...
# 31733        31733  18025687501
# 31734        31734  18025693601
# 31735        31735  18025694001
# 31736        31736  18025694002
# 31737        31737  18025694101
#
#                                             O_PURPOSE_x O_PURPOSE_y  \
# 1                                              HomeStop        Home
# 4                                              HomeStop        Home
# 5                                              HomeStop        Home
# 6      HomeStopHomeStopStopStopStopStopStopStopStopStop        Home
# 9                                      HomeStopStopStop        Home
# ...                                                 ...         ...
# 31733      HomeStopStopStopStopHomeStopStopStopStopStop        Home
# 31734                              HomeStopHomeStopStop        Home
# 31735                              HomeStopStopStopStop        Home
# 31736                              HomeStopStopHomeStop        Home
# 31737                                          HomeStop        Home
#
#                                          Home_Based_Tour Expected_Output  \
# 1                                           HomeStopHome           False
# 4                                           HomeStopHome           False
# 5                                           HomeStopHome           False
# 6      HomeStopHomeStopStopStopStopStopStopStopStopSt...           False
# 9                                   HomeStopStopStopHome           False
# ...                                                  ...             ...
# 31733   HomeStopStopStopStopHomeStopStopStopStopStopHome           False
# 31734                           HomeStopHomeStopStopHome           False
# 31735                           HomeStopStopStopStopHome           False
# 31736                           HomeStopStopHomeStopHome           False
# 31737                                       HomeStopHome           False
#
#       Unnamed: 0_y HOUSEHOLD_ID_x PERSNO           TRIPID  ...  \
# 1              5.5    140000271.0    3.0  1400000000000.0  ...
# 4             20.5    140000291.0    2.0  1400000000000.0  ...
# 5             22.5    140000299.0    1.0  1400000000000.0  ...
# 6             29.5    140000309.0    1.0  1400000000000.0  ...
# 9             50.5    140000324.0    1.0  1400000000000.0  ...
# ...            ...            ...    ...              ...  ...
# 31733     126848.0    180256875.0    1.0  1800000000000.0  ...
# 31734     126856.0    180256936.0    1.0  1800000000000.0  ...
# 31735     126861.0    180256940.0    1.0  1800000000000.0  ...
# 31736     126866.0    180256940.0    2.0  1800000000000.0  ...
# 31737     126869.5    180256941.0    1.0  1800000000000.0  ...
#
#       MPO_TD_SHOP_TIME PERSON_TRIPCOUNT WALK_BIKE_LOOP_TRIPS     WTPERFIN  \
# 1                 -9.0              2.0                 -9.0  136.4601132
# 4                 -9.0              2.0                 -9.0  88.69822541
# 5                 -9.0              2.0                 -9.0  58.04967412
# 6                 -9.0             12.0                  2.0   46.4357747
# 9                 -9.0              4.0                 -9.0  88.69822541
# ...                ...              ...                  ...          ...
# 31733             -9.0             11.0                  0.0  36.14685464
# 31734             30.0              5.0                  1.0        101.0
# 31735             15.0              5.0                  0.0        139.0
# 31736              0.0              5.0                  0.0        139.0
# 31737              0.0              2.0                  0.0        157.0
#
#       WWM_WTPERFIN AGE_IMP GENDER_IMP RACEETHNICITY_IMP MPO_RACEETHNICITY_IMP  \
# 1            152.0    -9.0       -9.0              -9.0                  -9.0
# 4             88.0    -9.0       -9.0              -9.0                  -9.0
# 5             58.0    -9.0       -9.0              -9.0                  -9.0
# 6             47.0    -9.0       -9.0              -9.0                  -9.0
# 9             89.0    -9.0       -9.0              -9.0                  -9.0
# ...            ...     ...        ...               ...                   ...
# 31733         36.0     0.0        0.0               0.0                  -9.0
# 31734        105.0     1.0        0.0               1.0                   1.0
# 31735        140.0     0.0        0.0               0.0                   0.0
# 31736        141.0     0.0        0.0               0.0                   0.0
# 31737        163.0     0.0        0.0               1.0                   1.0
#
#       DISABILITY_IMP
# 1               -9.0
# 4               -9.0
# 5               -9.0
# 6               -9.0
# 9               -9.0
# ...              ...
# 31733            0.0
# 31734            1.0
# 31735            0.0
# 31736            0.0
# 31737            0.0
#
# [16929 rows x 130 columns]

# %%
#analyzing Home Based WOrk trips 
df225=df2['RACEETHNICITY'].value_counts(normalize=True) * 100
df225
# Out:
# White       69.318920
# Black       13.527084
# Asian        7.661409
# Others       5.068226
# Hispanic     4.424361
# Name: RACEETHNICITY, dtype: float64

# %%
#analyzing Home Based WOrk trips 
#df226=df2['TRAVEL_MODE'].value_counts(normalize=True) * 100
#df226
# Out:
# Private car          68.633705
# School bus            4.684270
# Walk                  4.193987
# 5.5                   2.734952
# Bike                  2.604997
#                        ...
# 4.230769230769231     0.005907
# 10.75                 0.005907
# 3.727272727272727     0.005907
# 8.285714285714286     0.005907
# 4.153846153846154     0.005907
# Name: TRAVEL_MODE, Length: 195, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df221=df2['GENDER'].value_counts(normalize=True) * 100
df221
# Out:
# Female         54.220568
# Male           45.761711
# No response     0.017721
# Name: GENDER, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df222=df2['LICENSE'].value_counts(normalize=True) * 100
df222
# Out:
# With License    65.467541
# No License      34.337527
# No response      0.194932
# Name: LICENSE, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df223=df2['DISABILITY'].value_counts(normalize=True) * 100
df223
# Out:
# Not disabled    86.626499
# No response      9.079095
# Disabled         4.294406
# Name: DISABILITY, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df224=df2['EMPLOYMENT_STATUS'].value_counts(normalize=True) * 100
df224
# Out:
# Unemployed    34.851438
# Employed      32.766259
# Retired       27.355426
# Student        5.026877
# Name: EMPLOYMENT_STATUS, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df227=df2['Ageclass'].value_counts(normalize=True) * 100
df227
# Out:
# Adult           43.587926
# Elderly         24.862662
# Child           20.432394
# Toddler/baby     9.947427
# nan              1.169591
# Name: Ageclass, dtype: float64

# %%
#analyzing Home Based WOrk trips 
df22=df2['Home_Based_Tour'].value_counts(normalize=True) * 100
df22
# Out:
# HomeStopHome                                                        36.351822
# HomeStopStopHome                                                    14.430858
# HomeStopHomeStopHome                                                 9.965149
# HomeStopStopStopHome                                                 8.133971
# HomeStopStopStopStopHome                                             3.715518
#                                                                       ...
# HomeStopStopStopStopStopHomeStopHomeStopHomeStopHome                 0.005907
# HomeStopHomeStopStopHomeStopStopStopStopStopStopStopHome             0.005907
# HomeStopStopHomeStopStopStopHomeHome                                 0.005907
# HomeHomeStopStopStopStopStopHome                                     0.005907
# HomeStopHomeStopHomeStopStopStopStopStopHomeStopHomeStopStopHome     0.005907
# Name: Home_Based_Tour, Length: 281, dtype: float64

# %%
df22.to_csv('HBO tour.csv')

# %%
#analyzing Home Based WOrk trips 
df11=df1['Home_Based_Tour'].value_counts(normalize=True) * 100
df11
# Out:
# HomeWorkHome                                                    32.201215
# HomeWorkStopHome                                                11.796084
# HomeWorkHomeStopHome                                             6.164754
# HomeWorkStopWorkHome                                             4.037812
# HomeWorkStopStopHome                                             3.490885
#                                                                   ...
# HomeStopStopStopHomeStopWorkStopWorkStopStopStopStopHome         0.006752
# HomeStopStopStopHomeStopHomeStopHomeStopHomeWorkHomeStopHome     0.006752
# HomeStopHomeStopWorkStopWorkHomeStopHome                         0.006752
# HomeWorkWorkStopStopWorkHomeStopStopHome                         0.006752
# HomeWorkWorkWorkWorkStopWorkStopWorkWorkHome                     0.006752
# Name: Home_Based_Tour, Length: 880, dtype: float64

# %%
#af1=pd.concat([df1, af], axis=1, join='inner')
