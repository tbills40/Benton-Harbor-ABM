# %%
import pandas as pd
import numpy as np
from scipy.spatial import distance
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#locate files from computer

# %%
#Import anmd merger for demographics get the mean
file = pd.read_csv('DCmergedfiled.csv')
house = pd.read_csv('DChouse.csv')
# Out:
# /var/folders/fs/02s140qd6n97_sck15lvgycm0000gn/T/ipykernel_2543/4284060090.py:2: DtypeWarning: Columns (26,27,29,31,54,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv('DCmergedfiled.csv')

# %%
file
# Out:
#         Unnamed: 0  HOUSEHOLD_ID    PERSON_ID  PERSNO        TRIPID  \
# 0                0     140000271  14000027101       1  1.400000e+12
# 1                1     140000271  14000027101       1  1.400000e+12
# 2                2     140000271  14000027101       1  1.400000e+12
# 3                3     140000271  14000027101       1  1.400000e+12
# 4                4     140000271  14000027101       1  1.400000e+12
# ...            ...           ...          ...     ...           ...
# 126869      126869     180256941  18025694101       1  1.800000e+12
# 126870      126870     180256941  18025694101       1  1.800000e+12
# 126871      126871     180256941  18025694102       2  1.800000e+12
# 126872      126872     180256941  18025694102       2  1.800000e+12
# 126873      126873     180256941  18025694102       2  1.800000e+12
#
#         Dwelltime  TRIPNO  O_PURPOSE  O_ACTIVITY  MPO_O_ACTIVITY  ...  \
# 0             121       1          1           1              -9  ...
# ...

# %%
house
# Out:
#        HOUSEHOLD_ID  IN_TPB  IN_BMC  HOME_STATE_FIPS HOME_STATE_PUMA  \
# 0         140000271       1       1               24        24_01204
# 1         140000280       1       1               24        24_01204
# 2         140000284       1       1               24        24_01204
# 3         140000291       1       1               24        24_01204
# 4         140000299       1       1               24        24_01204
# ...             ...     ...     ...              ...             ...
# 18010     180256919       1       0               51        51_59301
# 18011     180256936       1       1               24        24_01003
# 18012     180256938       1       0               51        51_59301
# 18013     180256940       1       0               51        51_51246
# 18014     180256941       1       1               24        24_01105
#
#        AREA_TYPE  HOME_STATE_COUNTY_FIPS  HOME_TRACT_FIPS  HOME_TPB_TAZ  \
# ...

# %%
dff=(pd.merge(file, house, on='HOUSEHOLD_ID'))
dff
# Out:
#         Unnamed: 0  HOUSEHOLD_ID    PERSON_ID  PERSNO        TRIPID  \
# 0                0     140000271  14000027101       1  1.400000e+12
# 1                1     140000271  14000027101       1  1.400000e+12
# 2                2     140000271  14000027101       1  1.400000e+12
# 3                3     140000271  14000027101       1  1.400000e+12
# 4                4     140000271  14000027101       1  1.400000e+12
# ...            ...           ...          ...     ...           ...
# 126869      126869     180256941  18025694101       1  1.800000e+12
# 126870      126870     180256941  18025694101       1  1.800000e+12
# 126871      126871     180256941  18025694102       2  1.800000e+12
# 126872      126872     180256941  18025694102       2  1.800000e+12
# 126873      126873     180256941  18025694102       2  1.800000e+12
#
#         Dwelltime  TRIPNO  O_PURPOSE  O_ACTIVITY  MPO_O_ACTIVITY  ...  \
# 0             121       1          1           1              -9  ...
# ...

# %%
# locate and load file to Read 

dff.to_csv('DCfileswithhouse.csv')

# %%
aff = af.groupby(['PERSON_ID']).sum()
aff
