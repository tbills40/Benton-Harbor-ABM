# %%
#importations 
import pandas as pd
import pandas as pd
import numpy as np
from scipy.spatial import distance
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#locate files from computer

# %%
df = pd.read_csv('trippub.csv')
df
# Out:
#          HOUSEID  PERSONID  TDTRPNUM  STRTTIME  ENDTIME  TRVLCMIN  TRPMILES  \
# 0       30000007         1         1      1000     1015        15     5.244
# 1       30000007         1         2      1510     1530        20     5.149
# 2       30000007         2         1       700      900       120    84.004
# 3       30000007         2         2      1800     2030       150    81.628
# 4       30000007         3         1       845      900        15     2.250
# ...          ...       ...       ...       ...      ...       ...       ...
# 923567  50515573         1         1       810      837        27     1.168
# 923568  50515573         1         2      1320     1328         8     0.238
# 923569  50515573         1         3      1415     1420         5     0.238
# 923570  50515573         1         4      1820     1845        25     0.867
# 923571  50515573         1         5      1848     1855         7     0.325
#
# ...

# %%
df['Person'] = df['HOUSEID'].map(str) + '-' + df['PERSONID'].map(str)
df
# Out:
#          HOUSEID  PERSONID  TDTRPNUM  STRTTIME  ENDTIME  TRVLCMIN  TRPMILES  \
# 0       30000007         1         1      1000     1015        15     5.244
# 1       30000007         1         2      1510     1530        20     5.149
# 2       30000007         2         1       700      900       120    84.004
# 3       30000007         2         2      1800     2030       150    81.628
# 4       30000007         3         1       845      900        15     2.250
# ...          ...       ...       ...       ...      ...       ...       ...
# 923567  50515573         1         1       810      837        27     1.168
# 923568  50515573         1         2      1320     1328         8     0.238
# 923569  50515573         1         3      1415     1420         5     0.238
# 923570  50515573         1         4      1820     1845        25     0.867
# 923571  50515573         1         5      1848     1855         7     0.325
#
# ...

# %%
af = pd.read_csv('2017mergedontournhts1.csv')
af
# Out:
#         Unnamed: 0      Person  Tour  Stop  P_Destination   HOUSEID  PERSONID  \
# 0                0  30000007-1   1.0   NaN            1.0  30000007         1
# 1                1  30000007-2   1.0   NaN            1.0  30000007         2
# 2                2  30000007-3   1.0   NaN            1.0  30000007         3
# 3                3  30000008-1   1.0   NaN            1.0  30000008         1
# 4                4  30000012-1   1.0   7.0            1.0  30000012         1
# ...            ...         ...   ...   ...            ...       ...       ...
# 206585      206585  40794293-2   1.0   NaN            1.0  40794293         2
# 206586      206586  40794301-2   1.0   3.0            1.0  40794301         2
# 206587      206587  40794301-3   1.0   3.0            NaN  40794301         3
# 206588      206588  40794301-6   1.0   1.0            NaN  40794301         6
# 206589      206589  50515573-1   1.0   3.0            1.0  50515573         1
#
# ...

# %%
tripandmergedfile=af.merge(df, on='Person', how='left')
tripandmergedfile
# Out:
#         Unnamed: 0      Person  Tour  Stop  P_Destination  HOUSEID_x  \
# 0                0  30000007-1   1.0   NaN            1.0   30000007
# 1                0  30000007-1   1.0   NaN            1.0   30000007
# 2                1  30000007-2   1.0   NaN            1.0   30000007
# 3                1  30000007-2   1.0   NaN            1.0   30000007
# 4                2  30000007-3   1.0   NaN            1.0   30000007
# ...            ...         ...   ...   ...            ...        ...
# 880528      206589  50515573-1   1.0   3.0            1.0   50515573
# 880529      206589  50515573-1   1.0   3.0            1.0   50515573
# 880530      206589  50515573-1   1.0   3.0            1.0   50515573
# 880531      206589  50515573-1   1.0   3.0            1.0   50515573
# 880532      206589  50515573-1   1.0   3.0            1.0   50515573
#
#         PERSONID_x  R_AGE_x  EDUC_x  R_HISP  ...  OBHTNRNT  OBPPOPDN  OBRESDN  \
# ...

# %%
#
ff = tripandmergedfile.groupby(['Person']).first()
ff
# Out:
#             Unnamed: 0  Tour  Stop  P_Destination  HOUSEID_x  PERSONID_x  \
# Person
# 30000007-1           0   1.0   NaN            1.0   30000007           1
# 30000007-2           1   1.0   NaN            1.0   30000007           2
# 30000007-3           2   1.0   NaN            1.0   30000007           3
# 30000008-1           3   1.0   NaN            1.0   30000008           1
# 30000012-1           4   1.0   7.0            1.0   30000012           1
# ...                ...   ...   ...            ...        ...         ...
# 40794293-2      206585   1.0   NaN            1.0   40794293           2
# 40794301-2      206586   1.0   3.0            1.0   40794301           2
# 40794301-3      206587   1.0   3.0            NaN   40794301           3
# 40794301-6      206588   1.0   1.0            NaN   40794301           6
# 50515573-1      206589   1.0   3.0            1.0   50515573           1
#
#             R_AGE_x  EDUC_x  R_HISP  R_RELAT  ...  OBHTNRNT  OBPPOPDN  \
# ...

# %%
ff.to_csv('tripandmergedfile.csv')

# %%
pd.pivot_table(ff,index='TRPTRANS',values='WTPERFIN',aggfunc = lambda x:x.sum()/ff['WTPERFIN'].sum()*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 pd.pivot_table(ff,index='TRPTRANS',values='WTPERFIN',aggfunc = lambda x:x.sum()/ff['WTPERFIN'].sum()*100)
#
# TypeError: pivot_table() got multiple values for argument 'values'

# %%
pd.pivot_table(tripandmergedfile,index='TRPTRANS',values='WTPERFIN',aggfunc = lambda x:x.sum()/tripandmergedfile['WTPERFIN'].sum()*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 pd.pivot_table(tripandmergedfile,index='TRPTRANS',values='WTPERFIN',aggfunc = lambda x:x.sum()/tripandmergedfile['WTPERFIN'].sum()*100)
#
# TypeError: pivot_table() got multiple values for argument 'values'
